# %% [markdown]
# # Speech Emotion Recognition
# # MLP Model

# %% [markdown]
# ## 01) Importing Libraries

# %%
import sys
import os
import random
import math
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
import seaborn as sns

SRC_PATH = "../"
if SRC_PATH not in sys.path:
    sys.path.append(os.path.abspath(SRC_PATH))

from data_utils import load_data_pt, stratified_split, loss_accuracy_graphs, train_epoch, evaluate

# %% [markdown]
# ## 02) Setting Default Values

# %%
DATA_PATH = '../../data/extracted/ravdess_features_balanced_rebalanced.pt'
OUT_DIR = '../../models/CNN'

SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PATIENCE = 6

print(f"DATA_PATH : '{DATA_PATH}'")
print(f"OUT_DIR : '{OUT_DIR}'")
print(f"Device : {DEVICE}")
# Out:
# DATA_PATH : '../../data/extracted/ravdess_features_balanced_rebalanced.pt'
# OUT_DIR : '../../models/CNN'
# Device : cuda

# %% [markdown]
# ## 03) Creating the MLP Model

# %%
class MLPClassifier(nn.Module):
    def __init__(self, feat_dim, n_time, n_classes=8):
        super().__init__()
        in_dim = feat_dim * n_time
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_dim, 1024),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(1024, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, n_classes)
        )
    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ## 04) Creating the Training Method for MLP Model

# %%
def train(X, y, meta, epochs, batch_size, lr):
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    N, T, D = X.shape

    X_train, y_train, X_validation, y_validation, X_test, y_test = stratified_split(X, y)
    print("Splits: Train -", X_train.shape[0], ", Validation -", X_validation.shape[0], ", Test -", X_test.shape[0])

    train_dataset = TensorDataset(X_train, y_train)
    validation_dataset = TensorDataset(X_validation, y_validation)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)

    model = MLPClassifier(feat_dim=D, n_time=T, n_classes=8).to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    best_validation = 0.0
    
    os.makedirs(OUT_DIR, exist_ok=True)
    patience = 0

    loss_accuracy_data =  {"epochs": [], "train_loss" : [], "train_accuracy" : [], "validation_loss" : [], "validation_accuracy" : []}

    for epoch in range(1, epochs+1):
        train_loss, train_accuracy = train_epoch(model, train_loader, optimizer, criterion, DEVICE)
        validation_loss, validation_accuracy = evaluate(model, validation_loader, criterion, DEVICE)

        loss_accuracy_data["epochs"].append(epoch)
        loss_accuracy_data["train_loss"].append(train_loss)
        loss_accuracy_data["train_accuracy"].append(train_accuracy)
        loss_accuracy_data["validation_loss"].append(validation_loss)
        loss_accuracy_data["validation_accuracy"].append(validation_accuracy)
        
        print(f"[MLP] Epoch {epoch} TrainLoss {train_loss:.4f} TrainAccuracy {train_accuracy:.4f} ValidationLoss {validation_loss:.4f} ValidationAccuracy {validation_accuracy:.4f}")
        if validation_accuracy > best_validation:
            best_validation = validation_accuracy
            best_model = model.state_dict()
            best_meta = meta
            patience = 0
        else:
            patience += 1
        if patience >= PATIENCE:
            print("Early stopping.")
            break

    loss_accuracy_graphs(loss_accuracy_data)
    
    return model.state_dict(), meta, best_model, best_meta, X_test, y_test

# %% [markdown]
# ## 05) Load the Dataset

# %%
X, y, meta = load_data_pt(DATA_PATH)
print("Size of Loaded Data:", X.shape, "\nSize of Labels:", y.shape, "\nDevice:", DEVICE)
# Out:
# Size of Loaded Data: torch.Size([3072, 228, 180])
# Size of Labels: torch.Size([3072])
# Device: cuda

# %% [markdown]
# ## 06) Training the Model with Different Hyperparameter Values

# %% [markdown]
# ### (i) Training the Model with these Hyperparameter Values
# - Epochs = 40
# - Batch Size = 64
# - Learning Rate = 1e-3 = 0.001

# %%
epochs = 40
batch_size = 64
lr = 1e-3
model_data, meta, best_model, best_meta, X_test, y_test= train(X, y, meta, epochs, batch_size, lr)
# Out:
# Splits: Train - 2457 , Validation - 307 , Test - 308
# [MLP] Epoch 1 TrainLoss 3.0847 TrainAccuracy 0.2263 ValidationLoss 1.7570 ValidationAccuracy 0.3420
# [MLP] Epoch 2 TrainLoss 1.7340 TrainAccuracy 0.3114 ValidationLoss 1.5877 ValidationAccuracy 0.3485
# [MLP] Epoch 3 TrainLoss 1.5445 TrainAccuracy 0.3765 ValidationLoss 1.4361 ValidationAccuracy 0.4625
# [MLP] Epoch 4 TrainLoss 1.3646 TrainAccuracy 0.4737 ValidationLoss 1.2844 ValidationAccuracy 0.5016
# [MLP] Epoch 5 TrainLoss 1.2021 TrainAccuracy 0.5446 ValidationLoss 1.1319 ValidationAccuracy 0.5635
# [MLP] Epoch 6 TrainLoss 1.0824 TrainAccuracy 0.5906 ValidationLoss 0.9590 ValidationAccuracy 0.6808
# [MLP] Epoch 7 TrainLoss 0.8769 TrainAccuracy 0.6809 ValidationLoss 0.7653 ValidationAccuracy 0.7655
# [MLP] Epoch 8 TrainLoss 0.7500 TrainAccuracy 0.7293 ValidationLoss 0.6560 ValidationAccuracy 0.7818
# [MLP] Epoch 9 TrainLoss 0.6829 TrainAccuracy 0.7546 ValidationLoss 0.6564 ValidationAccuracy 0.7883
# [MLP] Epoch 10 TrainLoss 0.5916 TrainAccuracy 0.7835 ValidationLoss 0.4892 ValidationAccuracy 0.8404
# [MLP] Epoch 11 TrainLoss 0.5398 TrainAccuracy 0.8055 ValidationLoss 0.4912 ValidationAccuracy 0.8371
# [MLP] Epoch 12 TrainLoss 0.5310 TrainAccuracy 0.8042 ValidationLoss 0.4643 ValidationAccuracy 0.8567
# [MLP] Epoch 13 TrainLoss 0.5180 TrainAccuracy 0.8282 ValidationLoss 0.4771 ValidationAccuracy 0.8502
# [MLP] Epoch 14 TrainLoss 0.4083 TrainAccuracy 0.8600 ValidationLoss 0.3398 ValidationAccuracy 0.8893
# [MLP] Epoch 15 TrainLoss 0.3888 TrainAccuracy 0.8673 ValidationLoss 0.3603 ValidationAccuracy 0.9055
# [MLP] Epoch 16 TrainLoss 0.4201 TrainAccuracy 0.8519 ValidationLoss 0.3243 ValidationAccuracy 0.9121
# [MLP] Epoch 17 TrainLoss 0.3959 TrainAccuracy 0.8592 ValidationLoss 0.4188 ValidationAccuracy 0.8795
# [MLP] Epoch 18 TrainLoss 0.3843 TrainAccuracy 0.8649 ValidationLoss 0.3053 ValidationAccuracy 0.9088
# [MLP] Epoch 19 TrainLoss 0.3440 TrainAccuracy 0.8746 ValidationLoss 0.3038 ValidationAccuracy 0.9251
# [MLP] Epoch 20 TrainLoss 0.2909 TrainAccuracy 0.8917 ValidationLoss 0.2942 ValidationAccuracy 0.9186
# [MLP] Epoch 21 TrainLoss 0.2731 TrainAccuracy 0.9113 ValidationLoss 0.3234 ValidationAccuracy 0.9283
# [MLP] Epoch 22 TrainLoss 0.2975 TrainAccuracy 0.8999 ValidationLoss 0.3583 ValidationAccuracy 0.9121
# [MLP] Epoch 23 TrainLoss 0.2709 TrainAccuracy 0.9019 ValidationLoss 0.3552 ValidationAccuracy 0.9186
# [MLP] Epoch 24 TrainLoss 0.2498 TrainAccuracy 0.9072 ValidationLoss 0.2834 ValidationAccuracy 0.9414
# [MLP] Epoch 25 TrainLoss 0.2190 TrainAccuracy 0.9251 ValidationLoss 0.3118 ValidationAccuracy 0.9186
# [MLP] Epoch 26 TrainLoss 0.2273 TrainAccuracy 0.9194 ValidationLoss 0.2708 ValidationAccuracy 0.9153
# [MLP] Epoch 27 TrainLoss 0.2365 TrainAccuracy 0.9239 ValidationLoss 0.3693 ValidationAccuracy 0.9023
# [MLP] Epoch 28 TrainLoss 0.3428 TrainAccuracy 0.9019 ValidationLoss 0.2952 ValidationAccuracy 0.9153
# [MLP] Epoch 29 TrainLoss 0.2509 TrainAccuracy 0.9162 ValidationLoss 0.3469 ValidationAccuracy 0.9251
# [MLP] Epoch 30 TrainLoss 0.2628 TrainAccuracy 0.9170 ValidationLoss 0.3320 ValidationAccuracy 0.9251
# Early stopping.

# %% [markdown]
# ### (ii) Training the Model with these Hyperparameter Values
# - Epochs = 40
# - Batch Size = 32
# - Learning Rate = 1e-4 = 0.0001

# %%
epochs = 40
batch_size = 32
lr = 1e-4
model_data, meta, best_model, best_meta, X_test, y_test= train(X, y, meta, epochs, batch_size, lr)
# Out:
# Splits: Train - 2457 , Validation - 307 , Test - 308
# [MLP] Epoch 1 TrainLoss 1.7892 TrainAccuracy 0.3289 ValidationLoss 1.5125 ValidationAccuracy 0.4267
# [MLP] Epoch 2 TrainLoss 1.4433 TrainAccuracy 0.4542 ValidationLoss 1.2929 ValidationAccuracy 0.5114
# [MLP] Epoch 3 TrainLoss 1.2441 TrainAccuracy 0.5381 ValidationLoss 1.1707 ValidationAccuracy 0.6091
# [MLP] Epoch 4 TrainLoss 1.0604 TrainAccuracy 0.6109 ValidationLoss 0.9590 ValidationAccuracy 0.7068
# [MLP] Epoch 5 TrainLoss 0.8268 TrainAccuracy 0.7131 ValidationLoss 0.7607 ValidationAccuracy 0.7427
# [MLP] Epoch 6 TrainLoss 0.6790 TrainAccuracy 0.7611 ValidationLoss 0.6385 ValidationAccuracy 0.7980
# [MLP] Epoch 7 TrainLoss 0.5088 TrainAccuracy 0.8339 ValidationLoss 0.5162 ValidationAccuracy 0.8567
# [MLP] Epoch 8 TrainLoss 0.3931 TrainAccuracy 0.8820 ValidationLoss 0.4173 ValidationAccuracy 0.8990
# [MLP] Epoch 9 TrainLoss 0.3129 TrainAccuracy 0.9052 ValidationLoss 0.3786 ValidationAccuracy 0.8860
# [MLP] Epoch 10 TrainLoss 0.2406 TrainAccuracy 0.9271 ValidationLoss 0.2991 ValidationAccuracy 0.9218
# [MLP] Epoch 11 TrainLoss 0.1970 TrainAccuracy 0.9471 ValidationLoss 0.2579 ValidationAccuracy 0.9349
# [MLP] Epoch 12 TrainLoss 0.1450 TrainAccuracy 0.9589 ValidationLoss 0.2562 ValidationAccuracy 0.9218
# [MLP] Epoch 13 TrainLoss 0.1062 TrainAccuracy 0.9719 ValidationLoss 0.2057 ValidationAccuracy 0.9511
# [MLP] Epoch 14 TrainLoss 0.0888 TrainAccuracy 0.9784 ValidationLoss 0.2334 ValidationAccuracy 0.9316
# [MLP] Epoch 15 TrainLoss 0.0851 TrainAccuracy 0.9768 ValidationLoss 0.1974 ValidationAccuracy 0.9609
# [MLP] Epoch 16 TrainLoss 0.0866 TrainAccuracy 0.9784 ValidationLoss 0.2071 ValidationAccuracy 0.9414
# [MLP] Epoch 17 TrainLoss 0.0545 TrainAccuracy 0.9906 ValidationLoss 0.2046 ValidationAccuracy 0.9511
# [MLP] Epoch 18 TrainLoss 0.0529 TrainAccuracy 0.9870 ValidationLoss 0.2106 ValidationAccuracy 0.9544
# [MLP] Epoch 19 TrainLoss 0.0525 TrainAccuracy 0.9866 ValidationLoss 0.2291 ValidationAccuracy 0.9446
# [MLP] Epoch 20 TrainLoss 0.0477 TrainAccuracy 0.9890 ValidationLoss 0.2707 ValidationAccuracy 0.9349
# [MLP] Epoch 21 TrainLoss 0.0481 TrainAccuracy 0.9886 ValidationLoss 0.2810 ValidationAccuracy 0.9414
# Early stopping.

# %% [markdown]
# ### (iii) Training the Model with these Hyperparameter Values
# - Epochs = 50
# - Batch Size = 32
# - Learning Rate = 1e-3 = 0.001

# %%
epochs = 50
batch_size = 32
lr = 1e-3
model_data, meta, best_model, best_meta, X_test, y_test= train(X, y, meta, epochs, batch_size, lr)
# Out:
# Splits: Train - 2457 , Validation - 307 , Test - 308
# [MLP] Epoch 1 TrainLoss 2.7515 TrainAccuracy 0.2458 ValidationLoss 1.6942 ValidationAccuracy 0.3388
# [MLP] Epoch 2 TrainLoss 1.6449 TrainAccuracy 0.3480 ValidationLoss 1.4740 ValidationAccuracy 0.4104
# [MLP] Epoch 3 TrainLoss 1.4332 TrainAccuracy 0.4347 ValidationLoss 1.3033 ValidationAccuracy 0.4886
# [MLP] Epoch 4 TrainLoss 1.3546 TrainAccuracy 0.4799 ValidationLoss 1.1498 ValidationAccuracy 0.5733
# [MLP] Epoch 5 TrainLoss 1.1940 TrainAccuracy 0.5372 ValidationLoss 1.0621 ValidationAccuracy 0.5798
# [MLP] Epoch 6 TrainLoss 1.0657 TrainAccuracy 0.6020 ValidationLoss 0.9569 ValidationAccuracy 0.6775
# [MLP] Epoch 7 TrainLoss 0.9612 TrainAccuracy 0.6382 ValidationLoss 0.8922 ValidationAccuracy 0.6743
# [MLP] Epoch 8 TrainLoss 0.8531 TrainAccuracy 0.6797 ValidationLoss 0.7853 ValidationAccuracy 0.7231
# [MLP] Epoch 9 TrainLoss 0.7270 TrainAccuracy 0.7330 ValidationLoss 0.6580 ValidationAccuracy 0.7655
# [MLP] Epoch 10 TrainLoss 0.7341 TrainAccuracy 0.7391 ValidationLoss 0.7051 ValidationAccuracy 0.7524
# [MLP] Epoch 11 TrainLoss 0.6639 TrainAccuracy 0.7574 ValidationLoss 0.6269 ValidationAccuracy 0.8143
# [MLP] Epoch 12 TrainLoss 0.6232 TrainAccuracy 0.7786 ValidationLoss 0.5649 ValidationAccuracy 0.8274
# [MLP] Epoch 13 TrainLoss 0.5189 TrainAccuracy 0.8164 ValidationLoss 0.5217 ValidationAccuracy 0.8567
# [MLP] Epoch 14 TrainLoss 0.6065 TrainAccuracy 0.7900 ValidationLoss 0.4776 ValidationAccuracy 0.8339
# [MLP] Epoch 15 TrainLoss 0.4351 TrainAccuracy 0.8482 ValidationLoss 0.4514 ValidationAccuracy 0.8860
# [MLP] Epoch 16 TrainLoss 0.4053 TrainAccuracy 0.8531 ValidationLoss 0.4152 ValidationAccuracy 0.8599
# [MLP] Epoch 17 TrainLoss 0.4468 TrainAccuracy 0.8441 ValidationLoss 0.4582 ValidationAccuracy 0.8567
# [MLP] Epoch 18 TrainLoss 0.4738 TrainAccuracy 0.8462 ValidationLoss 0.3619 ValidationAccuracy 0.9153
# [MLP] Epoch 19 TrainLoss 0.3791 TrainAccuracy 0.8645 ValidationLoss 0.3397 ValidationAccuracy 0.9023
# [MLP] Epoch 20 TrainLoss 0.3863 TrainAccuracy 0.8742 ValidationLoss 0.3497 ValidationAccuracy 0.8827
# [MLP] Epoch 21 TrainLoss 0.3470 TrainAccuracy 0.8893 ValidationLoss 0.4372 ValidationAccuracy 0.8860
# [MLP] Epoch 22 TrainLoss 0.3070 TrainAccuracy 0.8938 ValidationLoss 0.3563 ValidationAccuracy 0.8990
# [MLP] Epoch 23 TrainLoss 0.3001 TrainAccuracy 0.8954 ValidationLoss 0.3024 ValidationAccuracy 0.9023
# [MLP] Epoch 24 TrainLoss 0.3651 TrainAccuracy 0.8795 ValidationLoss 0.3417 ValidationAccuracy 0.9218
# [MLP] Epoch 25 TrainLoss 0.3063 TrainAccuracy 0.9007 ValidationLoss 0.3680 ValidationAccuracy 0.9088
# [MLP] Epoch 26 TrainLoss 0.2615 TrainAccuracy 0.9044 ValidationLoss 0.2748 ValidationAccuracy 0.9251
# [MLP] Epoch 27 TrainLoss 0.2883 TrainAccuracy 0.8901 ValidationLoss 0.2920 ValidationAccuracy 0.9153
# [MLP] Epoch 28 TrainLoss 0.2843 TrainAccuracy 0.9096 ValidationLoss 0.3971 ValidationAccuracy 0.8925
# [MLP] Epoch 29 TrainLoss 0.3345 TrainAccuracy 0.8978 ValidationLoss 0.3167 ValidationAccuracy 0.9218
# [MLP] Epoch 30 TrainLoss 0.2755 TrainAccuracy 0.9096 ValidationLoss 0.3290 ValidationAccuracy 0.9283
# [MLP] Epoch 31 TrainLoss 0.2810 TrainAccuracy 0.9060 ValidationLoss 0.3096 ValidationAccuracy 0.9349
# [MLP] Epoch 32 TrainLoss 0.2561 TrainAccuracy 0.9105 ValidationLoss 0.3517 ValidationAccuracy 0.9414
# [MLP] Epoch 33 TrainLoss 0.2615 TrainAccuracy 0.9117 ValidationLoss 0.3132 ValidationAccuracy 0.9283
# [MLP] Epoch 34 TrainLoss 0.2952 TrainAccuracy 0.9080 ValidationLoss 0.2959 ValidationAccuracy 0.9251
# [MLP] Epoch 35 TrainLoss 0.3348 TrainAccuracy 0.8909 ValidationLoss 0.2618 ValidationAccuracy 0.9186
# [MLP] Epoch 36 TrainLoss 0.2856 TrainAccuracy 0.9027 ValidationLoss 0.2821 ValidationAccuracy 0.9218
# [MLP] Epoch 37 TrainLoss 0.2808 TrainAccuracy 0.9141 ValidationLoss 0.2285 ValidationAccuracy 0.9349
# [MLP] Epoch 38 TrainLoss 0.3297 TrainAccuracy 0.9101 ValidationLoss 0.3312 ValidationAccuracy 0.9349
# Early stopping.

# %% [markdown]
# ### (iv) Training the Model with these Hyperparameter Values
# - Epochs = 40
# - Batch Size = 32
# - Learning Rate = 1e-3 = 0.001

# %%
epochs = 40
batch_size = 32
lr = 1e-3
model_data, meta, best_model, best_meta, X_test, y_test= train(X, y, meta, epochs, batch_size, lr)
# Out:
# Splits: Train - 2457 , Validation - 307 , Test - 308
# [MLP] Epoch 1 TrainLoss 2.7515 TrainAccuracy 0.2458 ValidationLoss 1.6942 ValidationAccuracy 0.3388
# [MLP] Epoch 2 TrainLoss 1.6449 TrainAccuracy 0.3480 ValidationLoss 1.4740 ValidationAccuracy 0.4104
# [MLP] Epoch 3 TrainLoss 1.4332 TrainAccuracy 0.4347 ValidationLoss 1.3033 ValidationAccuracy 0.4886
# [MLP] Epoch 4 TrainLoss 1.3546 TrainAccuracy 0.4799 ValidationLoss 1.1498 ValidationAccuracy 0.5733
# [MLP] Epoch 5 TrainLoss 1.1940 TrainAccuracy 0.5372 ValidationLoss 1.0621 ValidationAccuracy 0.5798
# [MLP] Epoch 6 TrainLoss 1.0657 TrainAccuracy 0.6020 ValidationLoss 0.9569 ValidationAccuracy 0.6775
# [MLP] Epoch 7 TrainLoss 0.9612 TrainAccuracy 0.6382 ValidationLoss 0.8922 ValidationAccuracy 0.6743
# [MLP] Epoch 8 TrainLoss 0.8531 TrainAccuracy 0.6797 ValidationLoss 0.7853 ValidationAccuracy 0.7231
# [MLP] Epoch 9 TrainLoss 0.7270 TrainAccuracy 0.7330 ValidationLoss 0.6580 ValidationAccuracy 0.7655
# [MLP] Epoch 10 TrainLoss 0.7341 TrainAccuracy 0.7391 ValidationLoss 0.7051 ValidationAccuracy 0.7524
# [MLP] Epoch 11 TrainLoss 0.6639 TrainAccuracy 0.7574 ValidationLoss 0.6269 ValidationAccuracy 0.8143
# [MLP] Epoch 12 TrainLoss 0.6232 TrainAccuracy 0.7786 ValidationLoss 0.5649 ValidationAccuracy 0.8274
# [MLP] Epoch 13 TrainLoss 0.5189 TrainAccuracy 0.8164 ValidationLoss 0.5217 ValidationAccuracy 0.8567
# [MLP] Epoch 14 TrainLoss 0.6065 TrainAccuracy 0.7900 ValidationLoss 0.4776 ValidationAccuracy 0.8339
# [MLP] Epoch 15 TrainLoss 0.4351 TrainAccuracy 0.8482 ValidationLoss 0.4514 ValidationAccuracy 0.8860
# [MLP] Epoch 16 TrainLoss 0.4053 TrainAccuracy 0.8531 ValidationLoss 0.4152 ValidationAccuracy 0.8599
# [MLP] Epoch 17 TrainLoss 0.4468 TrainAccuracy 0.8441 ValidationLoss 0.4582 ValidationAccuracy 0.8567
# [MLP] Epoch 18 TrainLoss 0.4738 TrainAccuracy 0.8462 ValidationLoss 0.3619 ValidationAccuracy 0.9153
# [MLP] Epoch 19 TrainLoss 0.3791 TrainAccuracy 0.8645 ValidationLoss 0.3397 ValidationAccuracy 0.9023
# [MLP] Epoch 20 TrainLoss 0.3863 TrainAccuracy 0.8742 ValidationLoss 0.3497 ValidationAccuracy 0.8827
# [MLP] Epoch 21 TrainLoss 0.3470 TrainAccuracy 0.8893 ValidationLoss 0.4372 ValidationAccuracy 0.8860
# [MLP] Epoch 22 TrainLoss 0.3070 TrainAccuracy 0.8938 ValidationLoss 0.3563 ValidationAccuracy 0.8990
# [MLP] Epoch 23 TrainLoss 0.3001 TrainAccuracy 0.8954 ValidationLoss 0.3024 ValidationAccuracy 0.9023
# [MLP] Epoch 24 TrainLoss 0.3651 TrainAccuracy 0.8795 ValidationLoss 0.3417 ValidationAccuracy 0.9218
# [MLP] Epoch 25 TrainLoss 0.3063 TrainAccuracy 0.9007 ValidationLoss 0.3680 ValidationAccuracy 0.9088
# [MLP] Epoch 26 TrainLoss 0.2615 TrainAccuracy 0.9044 ValidationLoss 0.2748 ValidationAccuracy 0.9251
# [MLP] Epoch 27 TrainLoss 0.2883 TrainAccuracy 0.8901 ValidationLoss 0.2920 ValidationAccuracy 0.9153
# [MLP] Epoch 28 TrainLoss 0.2843 TrainAccuracy 0.9096 ValidationLoss 0.3971 ValidationAccuracy 0.8925
# [MLP] Epoch 29 TrainLoss 0.3345 TrainAccuracy 0.8978 ValidationLoss 0.3167 ValidationAccuracy 0.9218
# [MLP] Epoch 30 TrainLoss 0.2755 TrainAccuracy 0.9096 ValidationLoss 0.3290 ValidationAccuracy 0.9283
# [MLP] Epoch 31 TrainLoss 0.2810 TrainAccuracy 0.9060 ValidationLoss 0.3096 ValidationAccuracy 0.9349
# [MLP] Epoch 32 TrainLoss 0.2561 TrainAccuracy 0.9105 ValidationLoss 0.3517 ValidationAccuracy 0.9414
# [MLP] Epoch 33 TrainLoss 0.2615 TrainAccuracy 0.9117 ValidationLoss 0.3132 ValidationAccuracy 0.9283
# [MLP] Epoch 34 TrainLoss 0.2952 TrainAccuracy 0.9080 ValidationLoss 0.2959 ValidationAccuracy 0.9251
# [MLP] Epoch 35 TrainLoss 0.3348 TrainAccuracy 0.8909 ValidationLoss 0.2618 ValidationAccuracy 0.9186
# [MLP] Epoch 36 TrainLoss 0.2856 TrainAccuracy 0.9027 ValidationLoss 0.2821 ValidationAccuracy 0.9218
# [MLP] Epoch 37 TrainLoss 0.2808 TrainAccuracy 0.9141 ValidationLoss 0.2285 ValidationAccuracy 0.9349
# [MLP] Epoch 38 TrainLoss 0.3297 TrainAccuracy 0.9101 ValidationLoss 0.3312 ValidationAccuracy 0.9349
# Early stopping.

# %% [markdown]
# #### By Observing all the Graphs, both (iii) and (iv) seems the models with the Best Hyperparameter Values.
# #### Because, only number of Epochs has been changed in both (i) and (iv) and it stopped already at 38.
# #### Therefore (iv) can be assumed as the model with Best Hyperparameters,
# #### Therefore,
# - Best Epochs = 40
# - Best Batch Size = 32
# - Best Learning Rate = 1e-4 = 0.0001

# %% [markdown]
# ## 06) Saving the Models with Best Hyperparameter Values

# %%
best_path = os.path.join(OUT_DIR, "mlp_best.pt")
torch.save({'state_dict': model_data, 'meta': meta}, best_path)
print(f"Saved Best Model:, '{best_path}'")

save_path = os.path.join(OUT_DIR, "mlp.pt")
torch.save({'state_dict': model_data, 'meta': meta}, save_path)
print(f"Saved Best Model:, '{save_path}")
# Out:
# Saved Best Model:, '../../models/CNN/mlp_best.pt'
# Saved Best Model:, '../../models/CNN/mlp.pt

# %% [markdown]
# ## 07) Evaluating the MLP Model with Test Set of Data

# %%
def evaluate_model(X, y, meta, X_test, y_test):
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    N, T, D = X.shape
    model = MLPClassifier(feat_dim=D, n_time=T, n_classes=8).to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    model.load_state_dict(torch.load(best_path, map_location=DEVICE)['state_dict'])
    test_dataset = TensorDataset(X_test, y_test)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    model.eval()
    total_loss = 0.0
    total = 0
    correct = 0
    all_preds = []
    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(DEVICE)
            yb = yb.to(DEVICE)
            out = model(xb)
            loss = criterion(out, yb)
            total_loss += loss.item() * xb.size(0)
            preds = out.argmax(dim=1)
            all_preds.extend(preds.cpu().numpy())
            correct += (preds == yb).sum().item()
            total += xb.size(0)
    test_loss = total_loss/total
    test_accuracy = correct/total

    total_accuracy_score = accuracy_score(y_test, all_preds)
    full_classification_report = classification_report(y_test, all_preds, digits=4)
    final_f1_score = f1_score(y_test, all_preds, average='macro', zero_division=0)
    return test_loss, total_accuracy_score, final_f1_score, full_classification_report, all_preds

# %% [markdown]
# ## 08) Accuracy, Classification Report and Confusion Matrix

# %%
test_loss, total_accuracy_score, final_f1_score, full_classification_report, all_preds =  evaluate_model(X, y, meta, X_test, y_test)
print("--------Test Set Performance--------")
print(f"\nTest Loss: {test_loss}")
print(f"Accuracy: {total_accuracy_score}")
print(f"Macro F1 Score: {final_f1_score}\n\n")
print(f"--------Classification Report--------\n\n {full_classification_report}\n\n")

print("--------Confusion Maxtrix--------")
final_confusion_matrix = confusion_matrix(y_test, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(final_confusion_matrix, annot=True, fmt='d', cmap='Blues')
plt.title(f'Confusion Matrix on Test Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# --------Test Set Performance--------
#
# Test Loss: 0.11728758906776254
# Accuracy: 0.961038961038961
# Macro F1 Score: 0.9602609416328929
#
#
# --------Classification Report--------
#
#                precision    recall  f1-score   support
#
#            0     0.9500    1.0000    0.9744        38
#            1     0.9744    1.0000    0.9870        38
#            2     0.9500    1.0000    0.9744        38
#            3     1.0000    0.9744    0.9870        39
#            4     1.0000    0.9231    0.9600        39
#            5     0.9070    1.0000    0.9512        39
#            6     0.9744    1.0000    0.9870        38
#            7     0.9394    0.7949    0.8611        39
#
#     accuracy                         0.9610       308
#    macro avg     0.9619    0.9615    0.9603       308
# weighted avg     0.9619    0.9610    0.9600       308
#
#
#
# --------Confusion Maxtrix--------
